# %% [markdown]
# # Week 4 Homework Part 1 - Kendall Gilbert

# %% [markdown]
# ## Exercise 3.3
#
# In this Exercise, we will explore our temperature data by comparing spring temperatures between Kumpula and Rovaniemi. To do this we'll use some conditions to extract subsets of our data and then analyse these subsets using basic pandas functions. Notice that in this exercise, we will use data saved from the previous Exercise (2.2.6), hence you should finish that Exercise before this one. An overview of the tasks in this exercise:
#
# - Calculate the median temperatures for Kumpula and Rovaniemi for the summer of 2017
# - Select temperatures for May and June 2017 in separate DataFrames for each location
# - Calculate descriptive statistics for each month (May, June) and location (Kumpula, Rovaniemi)

# %% [markdown]
# ### Problem 1 - Read the data and calculate basic statistics
#
# Read in the CSV files generated in Exercise 2.2.6 to the variables `kumpula` and `rovaniemi` and answer to following questions:
#
# - What was the median Celsius temperature during the observed period in Helsinki Kumpula? Store the answer in a variable `kumpula_median`.
# - What was the median Celsius temperature during the observed period in Rovaniemi? Store the answer in a variable `rovaniemi_median`.

# %%
import pandas as pd

#Reads in csv files from previous exercise
kumpula = pd.read_csv("Kumpula_temps_May_Aug_2017.csv")
rovaniemi = pd.read_csv("Rovaniemi_temps_May_Aug_2017.csv")

#Calculates and stores median Celsius temperatures from each csv
kumpula_median = kumpula["Celsius"].median()
rovaniemi_median = rovaniemi["Celsius"].median()

print('The median temperature during the observed period in Helsinki Kumpula was', kumpula_median,'.\nThe median temperature during the observed period in Rovaniemi was',rovaniemi_median,'.')
# Out:
# The median temperature during the observed period in Helsinki Kumpula was 14.0 .
# The median temperature during the observed period in Rovaniemi was 11.0 .

# %% [markdown]
# ### Problem 2 - Select data and compare temperatures between months
#
# The median temperatures above consider data from the entire summer (May-Aug), hence the differences might not be so clear. Let's now find out the mean temperatures from May and June 2017 in Kumpula and Rovaniemi:
#
# - From the `kumpula` and `rovaniemi` DataFrames, select the rows where values of the `YR--MODAHRMN` column are from May 2017. Assign these selected rows into the variables `kumpula_may` and `rovaniemi_may`
# - Repeat the procedure for the month of June and assign those values into variables to `kumpula_june` and `rovaniemi_june`
# - Calculate and print the mean, min and max Celsius temperatures for both places in May and June using the new subset dataframes (kumpula_may, rovaniemi_may, kumpula_june, and rovaniemi_june). Answer to following questions:
#     - Does there seem to be a large difference in temperatures between the months?
#     - Is Rovaniemi a much colder place than Kumpula?

# %%
#Creates new column of month in each dataframe
kumpula["Month"] = kumpula["YR--MODAHRMN"].astype(str).str.slice(start=4,stop=6)
rovaniemi["Month"] = rovaniemi["YR--MODAHRMN"].astype(str).str.slice(start=4,stop=6)

#Creates 2 new dataframes of the values from from May for each dataframe
kumpula_may = kumpula.loc[(kumpula["Month"] == "05")]
rovaniemi_may = rovaniemi.loc[(rovaniemi["Month"] == "05")]

#Creates 2 new dataframes of the values from from June for each dataframe
kumpula_june = kumpula.loc[(kumpula["Month"] == "06")]
rovaniemi_june = rovaniemi.loc[(rovaniemi["Month"] == "06")]

#Creates a dataframe of desired statistics for kumpula and prints it
info_kumpula = {'Mean Celsius Temp':[kumpula_may['Celsius'].mean(),kumpula_june['Celsius'].mean()],'Min Celsius Temp':[kumpula_may['Celsius'].min(),kumpula_june['Celsius'].min()], 'Max Celsius Temp':[kumpula_may['Celsius'].max(),kumpula_june['Celsius'].max()]}
table_kumpula = pd.DataFrame(data=info_kumpula)
table_kumpula = table_kumpula.set_index(pd.Index(['May','June']))
table_kumpula = table_kumpula.style.set_caption('Kumpula Temperature Data')
display(table_kumpula)

print('\n')

#Creates a dataframe of desired statistics for rovaniemi and prints it
info_rovaniemi = {'Mean Celsius Temp':[rovaniemi_may['Celsius'].mean(),rovaniemi_june['Celsius'].mean()],'Min Celsius Temp':[rovaniemi_may['Celsius'].min(),rovaniemi_june['Celsius'].min()], 'Max Celsius Temp':[rovaniemi_may['Celsius'].max(),rovaniemi_june['Celsius'].max()]}
table_rovaniemi = pd.DataFrame(data=info_rovaniemi)
table_rovaniemi = table_rovaniemi.set_index(pd.Index(['May','June']))
table_rovaniemi = table_rovaniemi.style.set_caption('Rovaniemi Temperature Data')
display(table_rovaniemi)
# Out:
# <style type="text/css">
# </style>
# <table id="T_78c3d">
#   <caption>Kumpula Temperature Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78c3d_level0_col0" class="col_heading level0 col0" >Mean Celsius Temp</th>
#       <th id="T_78c3d_level0_col1" class="col_heading level0 col1" >Min Celsius Temp</th>
#       <th id="T_78c3d_level0_col2" class="col_heading level0 col2" >Max Celsius Temp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78c3d_level0_row0" class="row_heading level0 row0" >May</th>
#       <td id="T_78c3d_row0_col0" class="data row0 col0" >9.758435</td>
#       <td id="T_78c3d_row0_col1" class="data row0 col1" >-2</td>
#       <td id="T_78c3d_row0_col2" class="data row0 col2" >23</td>
#     </tr>
#     <tr>
#       <th id="T_78c3d_level0_row1" class="row_heading level0 row1" >June</th>
#       <td id="T_78c3d_row1_col0" class="data row1 col0" >13.732493</td>
#       <td id="T_78c3d_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_78c3d_row1_col2" class="data row1 col2" >24</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_41209">
#   <caption>Rovaniemi Temperature Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41209_level0_col0" class="col_heading level0 col0" >Mean Celsius Temp</th>
#       <th id="T_41209_level0_col1" class="col_heading level0 col1" >Min Celsius Temp</th>
#       <th id="T_41209_level0_col2" class="col_heading level0 col2" >Max Celsius Temp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41209_level0_row0" class="row_heading level0 row0" >May</th>
#       <td id="T_41209_row0_col0" class="data row0 col0" >2.986036</td>
#       <td id="T_41209_row0_col1" class="data row0 col1" >-7</td>
#       <td id="T_41209_row0_col2" class="data row0 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_41209_level0_row1" class="row_heading level0 row1" >June</th>
#       <td id="T_41209_row1_col0" class="data row1 col0" >11.017395</td>
#       <td id="T_41209_row1_col1" class="data row1 col1" >-1</td>
#       <td id="T_41209_row1_col2" class="data row1 col2" >23</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Answers to Questions
#
# There does not seem to be a big  difference in temperature from May to June at Kumpula, but it seems like there is a big difference at Rovaniemi.
#
# Yes Rovaniemi is much cooler than Kumpula.

# %% [markdown]
# ### Problem 3 - Parse daily temperatures by aggregating data
#
# In this problem, the aim is to aggregate the hourly temperature data for Kumpula and Rovaniemi weather stations to a daily level. Currently, there are at most three measurements per hour in the data, as you can see from the YR--MODAHRMN column:
#
# ```
#     USAF  YR--MODAHRMN  TEMP  MAX  MIN  Celsius
# 0  28450  201705010000  31.0  NaN  NaN       -1
# 1  28450  201705010020  30.0  NaN  NaN       -1
# 2  28450  201705010050  30.0  NaN  NaN       -1
# 3  28450  201705010100  31.0  NaN  NaN       -1
# 4  28450  201705010120  30.0  NaN  NaN       -1
# ```

# %% [markdown]
# In this problem you should:
#
# - Summarize the information for each day by aggregating (grouping) the DataFrame using the `groupby()` function.

# %%
#Creates a column for each day in kumpula and rovaniemi dataframes
kumpula["YR--MODA"] = kumpula["YR--MODAHRMN"].astype(str).str.slice(start=0,stop=8)
rovaniemi["YR--MODA"] = rovaniemi["YR--MODAHRMN"].astype(str).str.slice(start=0,stop=8)

#groups the dataframes for kumpula and rovaniemi for each day
grouped_kumpula = kumpula.groupby("YR--MODA")
grouped_rovaniemi = rovaniemi.groupby("YR--MODA")

# %% [markdown]
# - The output should be a new DataFrame where you have calculated mean, max and min Celsius temperatures for each day separately based on hourly values.

# %%
#Initializes empty lists for data
mean_value_series = []
min_value_series = []
max_value_series = []
time_series = []

#Loop that goes through each day in dataframe, calculates desired statistics, and appends to each series
for key, group in grouped_kumpula:
    mean_value = group['Celsius'].mean() 
    mean_value_series.append(mean_value)
    min_value = group['Celsius'].min()
    min_value_series.append(min_value)
    max_value = group['Celsius'].max()
    max_value_series.append(max_value)
    time_series.append(key)

#Creates and displays new dataframe with mean, max, and min temperatures for each day in dataframe
info = {'YR--MODA':time_series,'Mean Celsius':mean_value_series,'Min Celsius':min_value_series, 'Max Celsius':max_value_series}
table_grouped_kumpula = pd.DataFrame(data=info)
table_grouped_kumpula = table_grouped_kumpula.style.set_caption('Grouped Kumpula Temperature Data')
display(table_grouped_kumpula)
# Out:
# <style type="text/css">
# </style>
# <table id="T_76eba">
#   <caption>Grouped Kumpula Temperature Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76eba_level0_col0" class="col_heading level0 col0" >YR--MODA</th>
#       <th id="T_76eba_level0_col1" class="col_heading level0 col1" >Mean Celsius</th>
#       <th id="T_76eba_level0_col2" class="col_heading level0 col2" >Min Celsius</th>
#       <th id="T_76eba_level0_col3" class="col_heading level0 col3" >Max Celsius</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76eba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76eba_row0_col0" class="data row0 col0" >20170501</td>
#       <td id="T_76eba_row0_col1" class="data row0 col1" >7.625000</td>
#       <td id="T_76eba_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_76eba_row0_col3" class="data row0 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76eba_row1_col0" class="data row1 col0" >20170502</td>
#       <td id="T_76eba_row1_col1" class="data row1 col1" >9.750000</td>
#       <td id="T_76eba_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_76eba_row1_col3" class="data row1 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76eba_row2_col0" class="data row2 col0" >20170503</td>
#       <td id="T_76eba_row2_col1" class="data row2 col1" >9.208333</td>
#       <td id="T_76eba_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_76eba_row2_col3" class="data row2 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76eba_row3_col0" class="data row3 col0" >20170504</td>
#       <td id="T_76eba_row3_col1" class="data row3 col1" >6.666667</td>
#       <td id="T_76eba_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_76eba_row3_col3" class="data row3 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76eba_row4_col0" class="data row4 col0" >20170505</td>
#       <td id="T_76eba_row4_col1" class="data row4 col1" >10.250000</td>
#       <td id="T_76eba_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_76eba_row4_col3" class="data row4 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76eba_row5_col0" class="data row5 col0" >20170506</td>
#       <td id="T_76eba_row5_col1" class="data row5 col1" >10.958333</td>
#       <td id="T_76eba_row5_col2" class="data row5 col2" >6</td>
#       <td id="T_76eba_row5_col3" class="data row5 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76eba_row6_col0" class="data row6 col0" >20170507</td>
#       <td id="T_76eba_row6_col1" class="data row6 col1" >5.875000</td>
#       <td id="T_76eba_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_76eba_row6_col3" class="data row6 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76eba_row7_col0" class="data row7 col0" >20170508</td>
#       <td id="T_76eba_row7_col1" class="data row7 col1" >4.250000</td>
#       <td id="T_76eba_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_76eba_row7_col3" class="data row7 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76eba_row8_col0" class="data row8 col0" >20170509</td>
#       <td id="T_76eba_row8_col1" class="data row8 col1" >1.666667</td>
#       <td id="T_76eba_row8_col2" class="data row8 col2" >-2</td>
#       <td id="T_76eba_row8_col3" class="data row8 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76eba_row9_col0" class="data row9 col0" >20170510</td>
#       <td id="T_76eba_row9_col1" class="data row9 col1" >1.541667</td>
#       <td id="T_76eba_row9_col2" class="data row9 col2" >-2</td>
#       <td id="T_76eba_row9_col3" class="data row9 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_76eba_row10_col0" class="data row10 col0" >20170511</td>
#       <td id="T_76eba_row10_col1" class="data row10 col1" >2.708333</td>
#       <td id="T_76eba_row10_col2" class="data row10 col2" >-2</td>
#       <td id="T_76eba_row10_col3" class="data row10 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_76eba_row11_col0" class="data row11 col0" >20170512</td>
#       <td id="T_76eba_row11_col1" class="data row11 col1" >5.166667</td>
#       <td id="T_76eba_row11_col2" class="data row11 col2" >-2</td>
#       <td id="T_76eba_row11_col3" class="data row11 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_76eba_row12_col0" class="data row12 col0" >20170513</td>
#       <td id="T_76eba_row12_col1" class="data row12 col1" >7.583333</td>
#       <td id="T_76eba_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_76eba_row12_col3" class="data row12 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_76eba_row13_col0" class="data row13 col0" >20170514</td>
#       <td id="T_76eba_row13_col1" class="data row13 col1" >10.125000</td>
#       <td id="T_76eba_row13_col2" class="data row13 col2" >3</td>
#       <td id="T_76eba_row13_col3" class="data row13 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_76eba_row14_col0" class="data row14 col0" >20170515</td>
#       <td id="T_76eba_row14_col1" class="data row14 col1" >8.708333</td>
#       <td id="T_76eba_row14_col2" class="data row14 col2" >3</td>
#       <td id="T_76eba_row14_col3" class="data row14 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_76eba_row15_col0" class="data row15 col0" >20170516</td>
#       <td id="T_76eba_row15_col1" class="data row15 col1" >7.217391</td>
#       <td id="T_76eba_row15_col2" class="data row15 col2" >1</td>
#       <td id="T_76eba_row15_col3" class="data row15 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_76eba_row16_col0" class="data row16 col0" >20170517</td>
#       <td id="T_76eba_row16_col1" class="data row16 col1" >9.708333</td>
#       <td id="T_76eba_row16_col2" class="data row16 col2" >6</td>
#       <td id="T_76eba_row16_col3" class="data row16 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_76eba_row17_col0" class="data row17 col0" >20170518</td>
#       <td id="T_76eba_row17_col1" class="data row17 col1" >11.000000</td>
#       <td id="T_76eba_row17_col2" class="data row17 col2" >9</td>
#       <td id="T_76eba_row17_col3" class="data row17 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_76eba_row18_col0" class="data row18 col0" >20170519</td>
#       <td id="T_76eba_row18_col1" class="data row18 col1" >16.375000</td>
#       <td id="T_76eba_row18_col2" class="data row18 col2" >9</td>
#       <td id="T_76eba_row18_col3" class="data row18 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_76eba_row19_col0" class="data row19 col0" >20170520</td>
#       <td id="T_76eba_row19_col1" class="data row19 col1" >16.958333</td>
#       <td id="T_76eba_row19_col2" class="data row19 col2" >13</td>
#       <td id="T_76eba_row19_col3" class="data row19 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_76eba_level0_row20"

# %%
#Initializes empty lists for data
mean_value_series = []
min_value_series = []
max_value_series = []
time_series = []

#Loop that goes through each day in dataframe, calculates desired statistics, and appends to each series
for key, group in grouped_rovaniemi:
    mean_value = group['Celsius'].mean() 
    mean_value_series.append(mean_value)
    min_value = group['Celsius'].min()
    min_value_series.append(min_value)
    max_value = group['Celsius'].max()
    max_value_series.append(max_value)
    time_series.append(key)
    
#Creates and displays new dataframe with mean, max, and min temperatures for each day in dataframe
info = {'YR--MODA':time_series,'Mean Celsius':mean_value_series,'Min Celsius':min_value_series, 'Max Celsius':max_value_series}
table_grouped_rovaniemi = pd.DataFrame(data=info)
table_grouped_rovaniemi = table_grouped_rovaniemi.style.set_caption('Grouped Rovaniemi Temperature Data')
display(table_grouped_rovaniemi)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9626b">
#   <caption>Grouped Rovaniemi Temperature Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9626b_level0_col0" class="col_heading level0 col0" >YR--MODA</th>
#       <th id="T_9626b_level0_col1" class="col_heading level0 col1" >Mean Celsius</th>
#       <th id="T_9626b_level0_col2" class="col_heading level0 col2" >Min Celsius</th>
#       <th id="T_9626b_level0_col3" class="col_heading level0 col3" >Max Celsius</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9626b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9626b_row0_col0" class="data row0 col0" >20170501</td>
#       <td id="T_9626b_row0_col1" class="data row0 col1" >2.180556</td>
#       <td id="T_9626b_row0_col2" class="data row0 col2" >-1</td>
#       <td id="T_9626b_row0_col3" class="data row0 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9626b_row1_col0" class="data row1 col0" >20170502</td>
#       <td id="T_9626b_row1_col1" class="data row1 col1" >3.402778</td>
#       <td id="T_9626b_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_9626b_row1_col3" class="data row1 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9626b_row2_col0" class="data row2 col0" >20170503</td>
#       <td id="T_9626b_row2_col1" class="data row2 col1" >2.112676</td>
#       <td id="T_9626b_row2_col2" class="data row2 col2" >-1</td>
#       <td id="T_9626b_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9626b_row3_col0" class="data row3 col0" >20170504</td>
#       <td id="T_9626b_row3_col1" class="data row3 col1" >4.388889</td>
#       <td id="T_9626b_row3_col2" class="data row3 col2" >-1</td>
#       <td id="T_9626b_row3_col3" class="data row3 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9626b_row4_col0" class="data row4 col0" >20170505</td>
#       <td id="T_9626b_row4_col1" class="data row4 col1" >6.916667</td>
#       <td id="T_9626b_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_9626b_row4_col3" class="data row4 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9626b_row5_col0" class="data row5 col0" >20170506</td>
#       <td id="T_9626b_row5_col1" class="data row5 col1" >-0.416667</td>
#       <td id="T_9626b_row5_col2" class="data row5 col2" >-3</td>
#       <td id="T_9626b_row5_col3" class="data row5 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9626b_row6_col0" class="data row6 col0" >20170507</td>
#       <td id="T_9626b_row6_col1" class="data row6 col1" >-1.694444</td>
#       <td id="T_9626b_row6_col2" class="data row6 col2" >-6</td>
#       <td id="T_9626b_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9626b_row7_col0" class="data row7 col0" >20170508</td>
#       <td id="T_9626b_row7_col1" class="data row7 col1" >-1.901408</td>
#       <td id="T_9626b_row7_col2" class="data row7 col2" >-7</td>
#       <td id="T_9626b_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9626b_row8_col0" class="data row8 col0" >20170509</td>
#       <td id="T_9626b_row8_col1" class="data row8 col1" >-0.661972</td>
#       <td id="T_9626b_row8_col2" class="data row8 col2" >-3</td>
#       <td id="T_9626b_row8_col3" class="data row8 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9626b_row9_col0" class="data row9 col0" >20170510</td>
#       <td id="T_9626b_row9_col1" class="data row9 col1" >-1.323944</td>
#       <td id="T_9626b_row9_col2" class="data row9 col2" >-4</td>
#       <td id="T_9626b_row9_col3" class="data row9 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9626b_row10_col0" class="data row10 col0" >20170511</td>
#       <td id="T_9626b_row10_col1" class="data row10 col1" >-1.611111</td>
#       <td id="T_9626b_row10_col2" class="data row10 col2" >-4</td>
#       <td id="T_9626b_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9626b_row11_col0" class="data row11 col0" >20170512</td>
#       <td id="T_9626b_row11_col1" class="data row11 col1" >-0.319444</td>
#       <td id="T_9626b_row11_col2" class="data row11 col2" >-4</td>
#       <td id="T_9626b_row11_col3" class="data row11 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9626b_row12_col0" class="data row12 col0" >20170513</td>
#       <td id="T_9626b_row12_col1" class="data row12 col1" >-0.333333</td>
#       <td id="T_9626b_row12_col2" class="data row12 col2" >-3</td>
#       <td id="T_9626b_row12_col3" class="data row12 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9626b_row13_col0" class="data row13 col0" >20170514</td>
#       <td id="T_9626b_row13_col1" class="data row13 col1" >0.375000</td>
#       <td id="T_9626b_row13_col2" class="data row13 col2" >-4</td>
#       <td id="T_9626b_row13_col3" class="data row13 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9626b_row14_col0" class="data row14 col0" >20170515</td>
#       <td id="T_9626b_row14_col1" class="data row14 col1" >1.408451</td>
#       <td id="T_9626b_row14_col2" class="data row14 col2" >-3</td>
#       <td id="T_9626b_row14_col3" class="data row14 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9626b_row15_col0" class="data row15 col0" >20170516</td>
#       <td id="T_9626b_row15_col1" class="data row15 col1" >3.611111</td>
#       <td id="T_9626b_row15_col2" class="data row15 col2" >-2</td>
#       <td id="T_9626b_row15_col3" class="data row15 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9626b_row16_col0" class="data row16 col0" >20170517</td>
#       <td id="T_9626b_row16_col1" class="data row16 col1" >2.638889</td>
#       <td id="T_9626b_row16_col2" class="data row16 col2" >1</td>
#       <td id="T_9626b_row16_col3" class="data row16 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9626b_row17_col0" class="data row17 col0" >20170518</td>
#       <td id="T_9626b_row17_col1" class="data row17 col1" >5.263889</td>
#       <td id="T_9626b_row17_col2" class="data row17 col2" >1</td>
#       <td id="T_9626b_row17_col3" class="data row17 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9626b_row18_col0" class="data row18 col0" >20170519</td>
#       <td id="T_9626b_row18_col1" class="data row18 col1" >6.169014</td>
#       <td id="T_9626b_row18_col2" class="data row18 col2" >3</td>
#       <td id="T_9626b_row18_col3" class="data row18 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9626b_row19_col0" class="data row19 col0" >20170520</td>
#       <td id="T_9626b_row19_col1" class="data row19 col1" >4.542857</td>
#       <td id="T_9626b_row19_col2" class="data row19 col2" >2</td>
#       <td id="T_9626b_row19_col3" class="data row19 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9626b_level0_row20"

# %% [markdown]
# - Repeat the task for the two data sets you created in Problem 2 (May-August temperatures from Rovaniemi and Kumpula).

# %%
#Creates a column for each day in kumpula (may and june) and rovaniemi (may and june) dataframes
kumpula_may["YR--MODA"] = kumpula_may["YR--MODAHRMN"].astype(str).str.slice(start=0,stop=8)
rovaniemi_may["YR--MODA"] = rovaniemi_may["YR--MODAHRMN"].astype(str).str.slice(start=0,stop=8)
kumpula_june["YR--MODA"] = kumpula_june["YR--MODAHRMN"].astype(str).str.slice(start=0,stop=8)
rovaniemi_june["YR--MODA"] = rovaniemi_june["YR--MODAHRMN"].astype(str).str.slice(start=0,stop=8)

#groups the dataframes for kumpula and rovaniemi for each day
grouped_kumpula_may = kumpula_may.groupby("YR--MODA")
grouped_rovaniemi_may = rovaniemi_may.groupby("YR--MODA")
grouped_kumpula_june = kumpula_june.groupby("YR--MODA")
grouped_rovaniemi_june = rovaniemi_june.groupby("YR--MODA")

#Initializes empty lists for data
mean_value_series = []
min_value_series = []
max_value_series = []
time_series = []

#Loop that goes through each day in dataframe, calculates desired statistics, and appends to each series
for key, group in grouped_kumpula_may:
    mean_value = group['Celsius'].mean() 
    mean_value_series.append(mean_value)
    min_value = group['Celsius'].min()
    min_value_series.append(min_value)
    max_value = group['Celsius'].max()
    max_value_series.append(max_value)
    time_series.append(key)

#Creates and displays new dataframe with mean, max, and min temperatures for each day in dataframe
info = {'YR--MODA':time_series,'Mean Celsius':mean_value_series,'Min Celsius':min_value_series, 'Max Celsius':max_value_series}
table_grouped_kumpula_may = pd.DataFrame(data=info)
table_grouped_kumpula_may = table_grouped_kumpula_may.style.set_caption('Grouped Kumpula May Temperature Data')
display(table_grouped_kumpula_may)
print('\n')

#Initializes empty lists for data
mean_value_series = []
min_value_series = []
max_value_series = []
time_series = []

#Loop that goes through each day in dataframe, calculates desired statistics, and appends to each series
for key, group in grouped_kumpula_june:
    mean_value = group['Celsius'].mean() 
    mean_value_series.append(mean_value)
    min_value = group['Celsius'].min()
    min_value_series.append(min_value)
    max_value = group['Celsius'].max()
    max_value_series.append(max_value)
    time_series.append(key)

#Creates and displays new dataframe with mean, max, and min temperatures for each day in dataframe
info = {'YR--MODA':time_series,'Mean Celsius':mean_value_series,'Min Celsius':min_value_series, 'Max Celsius':max_value_series}
table_grouped_kumpula_june = pd.DataFrame(data=info)
table_grouped_kumpula_june = table_grouped_kumpula_june.style.set_caption('Grouped Kumpula June Temperature Data')
display(table_grouped_kumpula_june)
print('\n')

#Initializes empty lists for data
mean_value_series = []
min_value_series = []
max_value_series = []
time_series = []

#Loop that goes through each day in dataframe, calculates desired statistics, and appends to each series
for key, group in grouped_rovaniemi_may:
    mean_value = group['Celsius'].mean() 
    mean_value_series.append(mean_value)
    min_value = group['Celsius'].min()
    min_value_series.append(min_value)
    max_value = group['Celsius'].max()
    max_value_series.append(max_value)
    time_series.append(key)

#Creates and displays new dataframe with mean, max, and min temperatures for each day in dataframe
info = {'YR--MODA':time_series,'Mean Celsius':mean_value_series,'Min Celsius':min_value_series, 'Max Celsius':max_value_series}
table_grouped_rovaniemi_may = pd.DataFrame(data=info)
table_grouped_rovaniemi_may = table_grouped_rovaniemi_may.style.set_caption('Grouped Rovaniemi May Temperature Data')
display(table_grouped_rovaniemi_may)
print('\n')

#Initializes empty lists for data
mean_value_series = []
min_value_series = []
max_value_series = []
time_series = []

#Loop that goes through each day in dataframe, calculates desired statistics, and appends to each series
for key, group in grouped_rovaniemi_june:
    mean_value = group['Celsius'].mean() 
    mean_value_series.append(mean_value)
    min_value = group['Celsius'].min()
    min_value_series.append(min_value)
    max_value = group['Celsius'].max()
    max_value_series.append(max_value)
    time_series.append(key)

#Creates and displays new dataframe with mean, max, and min temperatures for each day in dataframe
info = {'YR--MODA':time_series,'Mean Celsius':mean_value_series,'Min Celsius':min_value_series, 'Max Celsius':max_value_series}
table_grouped_rovaniemi_june = pd.DataFrame(data=info)
table_grouped_rovaniemi_june = table_grouped_rovaniemi_june.style.set_caption('Grouped Rovaniemi June Temperature Data')
display(table_grouped_rovaniemi_june)
# Out:
# /tmp/ipykernel_69508/1006915770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kumpula_may["YR--MODA"] = kumpula_may["YR--MODAHRMN"].astype(str).str.slice(start=0,stop=8)
# /tmp/ipykernel_69508/1006915770.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rovaniemi_may["YR--MODA"] = rovaniemi_may["YR--MODAHRMN"].astype(str).str.slice(start=0,stop=8)
# /tmp/ipykernel_69508/1006915770.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kumpula_june["YR--MODA"] = kumpula_june["YR--MODAHRMN"].astype(str).str.slice(start=0,stop=8)
# /tmp/ipykernel_69508/1006915770.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rovaniemi_june["YR--MODA"] = rovaniemi_june["YR--MODAHRMN"].astype(str).str.slice(start=0,stop=8)
# <style type="text/css">
# </style>
# <table id="T_8c5e4">
#   <caption>Grouped Kumpula May Temperature Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c5e4_level0_col0" class="col_heading level0 col0" >YR--MODA</th>
#       <th id="T_8c5e4_level0_col1" class="col_heading level0 col1" >Mean Celsius</th>
#       <th id="T_8c5e4_level0_col2" class="col_heading level0 col2" >Min Celsius</th>
#       <th id="T_8c5e4_level0_col3" class="col_heading level0 col3" >Max Celsius</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c5e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c5e4_row0_col0" class="data row0 col0" >20170501</td>
#       <td id="T_8c5e4_row0_col1" class="data row0 col1" >7.625000</td>
#       <td id="T_8c5e4_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_8c5e4_row0_col3" class="data row0 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8c5e4_row1_col0" class="data row1 col0" >20170502</td>
#       <td id="T_8c5e4_row1_col1" class="data row1 col1" >9.750000</td>
#       <td id="T_8c5e4_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_8c5e4_row1_col3" class="data row1 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8c5e4_row2_col0" class="data row2 col0" >20170503</td>
#       <td id="T_8c5e4_row2_col1" class="data row2 col1" >9.208333</td>
#       <td id="T_8c5e4_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_8c5e4_row2_col3" class="data row2 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8c5e4_row3_col0" class="data row3 col0" >20170504</td>
#       <td id="T_8c5e4_row3_col1" class="data row3 col1" >6.666667</td>
#       <td id="T_8c5e4_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_8c5e4_row3_col3" class="data row3 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8c5e4_row4_col0" class="data row4 col0" >20170505</td>
#       <td id="T_8c5e4_row4_col1" class="data row4 col1" >10.250000</td>
#       <td id="T_8c5e4_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_8c5e4_row4_col3" class="data row4 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8c5e4_row5_col0" class="data row5 col0" >20170506</td>
#       <td id="T_8c5e4_row5_col1" class="data row5 col1" >10.958333</td>
#       <td id="T_8c5e4_row5_col2" class="data row5 col2" >6</td>
#       <td id="T_8c5e4_row5_col3" class="data row5 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8c5e4_row6_col0" class="data row6 col0" >20170507</td>
#       <td id="T_8c5e4_row6_col1" class="data row6 col1" >5.875000</td>
#       <td id="T_8c5e4_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_8c5e4_row6_col3" class="data row6 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8c5e4_row7_col0" class="data row7 col0" >20170508</td>
#       <td id="T_8c5e4_row7_col1" class="data row7 col1" >4.250000</td>
#       <td id="T_8c5e4_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_8c5e4_row7_col3" class="data row7 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8c5e4_row8_col0" class="data row8 col0" >20170509</td>
#       <td id="T_8c5e4_row8_col1" class="data row8 col1" >1.666667</td>
#       <td id="T_8c5e4_row8_col2" class="data row8 col2" >-2</td>
#       <td id="T_8c5e4_row8_col3" class="data row8 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8c5e4_row9_col0" class="data row9 col0" >20170510</td>
#       <td id="T_8c5e4_row9_col1" class="data row9 col1" >1.541667</td>
#       <td id="T_8c5e4_row9_col2" class="data row9 col2" >-2</td>
#       <td id="T_8c5e4_row9_col3" class="data row9 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8c5e4_row10_col0" class="data row10 col0" >20170511</td>
#       <td id="T_8c5e4_row10_col1" class="data row10 col1" >2.708333</td>
#       <td id="T_8c5e4_row10_col2" class="data row10 col2" >-2</td>
#       <td id="T_8c5e4_row10_col3" class="data row10 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8c5e4_row11_col0" class="data row11 col0" >20170512</td>
#       <td id="T_8c5e4_row11_col1" class="data row11 col1" >5.166667</td>
#       <td id="T_8c5e4_row11_col2" class="data row11 col2" >-2</td>
#       <td id="T_8c5e4_row11_col3" class="data row11 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8c5e4_row12_col0" class="data row12 col0" >20170513</td>
#       <td id="T_8c5e4_row12_col1" class="data row12 col1" >7.583333</td>
#       <td id="T_8c5e4_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_8c5e4_row12_col3" class="data row12 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8c5e4_row13_col0" class="data row13 col0" >20170514</td>
#       <td id="T_8c5e4_row13_col1" class="data row13 col1" >10.125000</td>
#       <td id="T_8c5e4_row13_col2" class="data row13 col2" >3</td>
#       <td id="T_8c5e4_row13_col3" class="data row13 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8c5e4_row14_col0" class="data row14 col0" >20170515</td>
#       <td id="T_8c5e4_row14_col1" class="data row14 col1" >8.708333</td>
#       <td id="T_8c5e4_row14_col2" class="data row14 col2" >3</td>
#       <td id="T_8c5e4_row14_col3" class="data row14 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8c5e4_row15_col0" class="data row15 col0" >20170516</td>
#       <td id="T_8c5e4_row15_col1" class="data row15 col1" >7.217391</td>
#       <td id="T_8c5e4_row15_col2" class="data row15 col2" >1</td>
#       <td id="T_8c5e4_row15_col3" class="data row15 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8c5e4_row16_col0" class="data row16 col0" >20170517</td>
#       <td id="T_8c5e4_row16_col1" class="data row16 col1" >9.708333</td>
#       <td id="T_8c5e4_row16_col2" class="data row16 col2" >6</td>
#       <td id="T_8c5e4_row16_col3" class="data row16 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8c5e4_row17_col0" class="data row17 col0" >20170518</td>
#       <td id="T_8c5e4_row17_col1" class="data row17 col1" >11.000000</td>
#       <td id="T_8c5e4_row17_col2" class="data row17 col2" >9</td>
#       <td id="T_8c5e4_row17_col3" class="data row17 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8c5e4_row18_col0" class="data row18 col0" >20170519</td>
#       <td id="T_8c5e4_row18_col1" class="data row18 col1" >16.375000</td>
#       <td id="T_8c5e4_row18_col2" class="data row18 col2" >9</td>
#       <td id="T_8c5e4_row18_col3" class="data row18 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8c5e4_row19_col0" class="data row19 col0" >20170520</td>
#       <td id="T_8c5e4_row19_col1" class="data row19 col1" >16.958333</td>
#       <td id="T_8c5e4_row19_col2" class="data row19 col2" >13</td>
#       <td id="T_8c5e4_row19_col3" class="data row19 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_8c5e4_level0_ro
# <style type="text/css">
# </style>
# <table id="T_a6545">
#   <caption>Grouped Kumpula June Temperature Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6545_level0_col0" class="col_heading level0 col0" >YR--MODA</th>
#       <th id="T_a6545_level0_col1" class="col_heading level0 col1" >Mean Celsius</th>
#       <th id="T_a6545_level0_col2" class="col_heading level0 col2" >Min Celsius</th>
#       <th id="T_a6545_level0_col3" class="col_heading level0 col3" >Max Celsius</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6545_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6545_row0_col0" class="data row0 col0" >20170601</td>
#       <td id="T_a6545_row0_col1" class="data row0 col1" >6.583333</td>
#       <td id="T_a6545_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_a6545_row0_col3" class="data row0 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6545_row1_col0" class="data row1 col0" >20170602</td>
#       <td id="T_a6545_row1_col1" class="data row1 col1" >6.125000</td>
#       <td id="T_a6545_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_a6545_row1_col3" class="data row1 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6545_row2_col0" class="data row2 col0" >20170603</td>
#       <td id="T_a6545_row2_col1" class="data row2 col1" >10.166667</td>
#       <td id="T_a6545_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_a6545_row2_col3" class="data row2 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6545_row3_col0" class="data row3 col0" >20170604</td>
#       <td id="T_a6545_row3_col1" class="data row3 col1" >9.916667</td>
#       <td id="T_a6545_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_a6545_row3_col3" class="data row3 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6545_row4_col0" class="data row4 col0" >20170605</td>
#       <td id="T_a6545_row4_col1" class="data row4 col1" >10.333333</td>
#       <td id="T_a6545_row4_col2" class="data row4 col2" >9</td>
#       <td id="T_a6545_row4_col3" class="data row4 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6545_row5_col0" class="data row5 col0" >20170606</td>
#       <td id="T_a6545_row5_col1" class="data row5 col1" >14.541667</td>
#       <td id="T_a6545_row5_col2" class="data row5 col2" >8</td>
#       <td id="T_a6545_row5_col3" class="data row5 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6545_row6_col0" class="data row6 col0" >20170607</td>
#       <td id="T_a6545_row6_col1" class="data row6 col1" >16.458333</td>
#       <td id="T_a6545_row6_col2" class="data row6 col2" >9</td>
#       <td id="T_a6545_row6_col3" class="data row6 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6545_row7_col0" class="data row7 col0" >20170608</td>
#       <td id="T_a6545_row7_col1" class="data row7 col1" >12.333333</td>
#       <td id="T_a6545_row7_col2" class="data row7 col2" >11</td>
#       <td id="T_a6545_row7_col3" class="data row7 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6545_row8_col0" class="data row8 col0" >20170609</td>
#       <td id="T_a6545_row8_col1" class="data row8 col1" >14.000000</td>
#       <td id="T_a6545_row8_col2" class="data row8 col2" >11</td>
#       <td id="T_a6545_row8_col3" class="data row8 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6545_row9_col0" class="data row9 col0" >20170610</td>
#       <td id="T_a6545_row9_col1" class="data row9 col1" >16.291667</td>
#       <td id="T_a6545_row9_col2" class="data row9 col2" >11</td>
#       <td id="T_a6545_row9_col3" class="data row9 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a6545_row10_col0" class="data row10 col0" >20170611</td>
#       <td id="T_a6545_row10_col1" class="data row10 col1" >16.791667</td>
#       <td id="T_a6545_row10_col2" class="data row10 col2" >13</td>
#       <td id="T_a6545_row10_col3" class="data row10 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a6545_row11_col0" class="data row11 col0" >20170612</td>
#       <td id="T_a6545_row11_col1" class="data row11 col1" >12.625000</td>
#       <td id="T_a6545_row11_col2" class="data row11 col2" >12</td>
#       <td id="T_a6545_row11_col3" class="data row11 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a6545_row12_col0" class="data row12 col0" >20170613</td>
#       <td id="T_a6545_row12_col1" class="data row12 col1" >12.625000</td>
#       <td id="T_a6545_row12_col2" class="data row12 col2" >9</td>
#       <td id="T_a6545_row12_col3" class="data row12 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a6545_row13_col0" class="data row13 col0" >20170614</td>
#       <td id="T_a6545_row13_col1" class="data row13 col1" >14.791667</td>
#       <td id="T_a6545_row13_col2" class="data row13 col2" >7</td>
#       <td id="T_a6545_row13_col3" class="data row13 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a6545_row14_col0" class="data row14 col0" >20170615</td>
#       <td id="T_a6545_row14_col1" class="data row14 col1" >15.250000</td>
#       <td id="T_a6545_row14_col2" class="data row14 col2" >9</td>
#       <td id="T_a6545_row14_col3" class="data row14 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a6545_row15_col0" class="data row15 col0" >20170616</td>
#       <td id="T_a6545_row15_col1" class="data row15 col1" >18.500000</td>
#       <td id="T_a6545_row15_col2" class="data row15 col2" >12</td>
#       <td id="T_a6545_row15_col3" class="data row15 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a6545_row16_col0" class="data row16 col0" >20170617</td>
#       <td id="T_a6545_row16_col1" class="data row16 col1" >19.458333</td>
#       <td id="T_a6545_row16_col2" class="data row16 col2" >14</td>
#       <td id="T_a6545_row16_col3" class="data row16 col3" >24</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a6545_row17_col0" class="data row17 col0" >20170618</td>
#       <td id="T_a6545_row17_col1" class="data row17 col1" >16.875000</td>
#       <td id="T_a6545_row17_col2" class="data row17 col2" >14</td>
#       <td id="T_a6545_row17_col3" class="data row17 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a6545_row18_col0" class="data row18 col0" >20170619</td>
#       <td id="T_a6545_row18_col1" class="data row18 col1" >17.791667</td>
#       <td id="T_a6545_row18_col2" class="data row18 col2" >13</td>
#       <td id="T_a6545_row18_col3" class="data row18 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_a6545_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a6545_row19_col0" class="data row19 col0" >20170620</td>
#       <td id="T_a6545_row19_col1" class="data row19 col1" >12.791667</td>
#       <td id="T_a6545_row19_col2" class="data row19 col2" >10</td>
#       <td id="T_a6545_row19_col3" class="data row19 col3" >17</td>
#     </tr>
#     <tr>
#       <th
# <style type="text/css">
# </style>
# <table id="T_5ae9f">
#   <caption>Grouped Rovaniemi May Temperature Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ae9f_level0_col0" class="col_heading level0 col0" >YR--MODA</th>
#       <th id="T_5ae9f_level0_col1" class="col_heading level0 col1" >Mean Celsius</th>
#       <th id="T_5ae9f_level0_col2" class="col_heading level0 col2" >Min Celsius</th>
#       <th id="T_5ae9f_level0_col3" class="col_heading level0 col3" >Max Celsius</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ae9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ae9f_row0_col0" class="data row0 col0" >20170501</td>
#       <td id="T_5ae9f_row0_col1" class="data row0 col1" >2.180556</td>
#       <td id="T_5ae9f_row0_col2" class="data row0 col2" >-1</td>
#       <td id="T_5ae9f_row0_col3" class="data row0 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5ae9f_row1_col0" class="data row1 col0" >20170502</td>
#       <td id="T_5ae9f_row1_col1" class="data row1 col1" >3.402778</td>
#       <td id="T_5ae9f_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_5ae9f_row1_col3" class="data row1 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5ae9f_row2_col0" class="data row2 col0" >20170503</td>
#       <td id="T_5ae9f_row2_col1" class="data row2 col1" >2.112676</td>
#       <td id="T_5ae9f_row2_col2" class="data row2 col2" >-1</td>
#       <td id="T_5ae9f_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5ae9f_row3_col0" class="data row3 col0" >20170504</td>
#       <td id="T_5ae9f_row3_col1" class="data row3 col1" >4.388889</td>
#       <td id="T_5ae9f_row3_col2" class="data row3 col2" >-1</td>
#       <td id="T_5ae9f_row3_col3" class="data row3 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5ae9f_row4_col0" class="data row4 col0" >20170505</td>
#       <td id="T_5ae9f_row4_col1" class="data row4 col1" >6.916667</td>
#       <td id="T_5ae9f_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_5ae9f_row4_col3" class="data row4 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5ae9f_row5_col0" class="data row5 col0" >20170506</td>
#       <td id="T_5ae9f_row5_col1" class="data row5 col1" >-0.416667</td>
#       <td id="T_5ae9f_row5_col2" class="data row5 col2" >-3</td>
#       <td id="T_5ae9f_row5_col3" class="data row5 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5ae9f_row6_col0" class="data row6 col0" >20170507</td>
#       <td id="T_5ae9f_row6_col1" class="data row6 col1" >-1.694444</td>
#       <td id="T_5ae9f_row6_col2" class="data row6 col2" >-6</td>
#       <td id="T_5ae9f_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5ae9f_row7_col0" class="data row7 col0" >20170508</td>
#       <td id="T_5ae9f_row7_col1" class="data row7 col1" >-1.901408</td>
#       <td id="T_5ae9f_row7_col2" class="data row7 col2" >-7</td>
#       <td id="T_5ae9f_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5ae9f_row8_col0" class="data row8 col0" >20170509</td>
#       <td id="T_5ae9f_row8_col1" class="data row8 col1" >-0.661972</td>
#       <td id="T_5ae9f_row8_col2" class="data row8 col2" >-3</td>
#       <td id="T_5ae9f_row8_col3" class="data row8 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5ae9f_row9_col0" class="data row9 col0" >20170510</td>
#       <td id="T_5ae9f_row9_col1" class="data row9 col1" >-1.323944</td>
#       <td id="T_5ae9f_row9_col2" class="data row9 col2" >-4</td>
#       <td id="T_5ae9f_row9_col3" class="data row9 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5ae9f_row10_col0" class="data row10 col0" >20170511</td>
#       <td id="T_5ae9f_row10_col1" class="data row10 col1" >-1.611111</td>
#       <td id="T_5ae9f_row10_col2" class="data row10 col2" >-4</td>
#       <td id="T_5ae9f_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5ae9f_row11_col0" class="data row11 col0" >20170512</td>
#       <td id="T_5ae9f_row11_col1" class="data row11 col1" >-0.319444</td>
#       <td id="T_5ae9f_row11_col2" class="data row11 col2" >-4</td>
#       <td id="T_5ae9f_row11_col3" class="data row11 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5ae9f_row12_col0" class="data row12 col0" >20170513</td>
#       <td id="T_5ae9f_row12_col1" class="data row12 col1" >-0.333333</td>
#       <td id="T_5ae9f_row12_col2" class="data row12 col2" >-3</td>
#       <td id="T_5ae9f_row12_col3" class="data row12 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5ae9f_row13_col0" class="data row13 col0" >20170514</td>
#       <td id="T_5ae9f_row13_col1" class="data row13 col1" >0.375000</td>
#       <td id="T_5ae9f_row13_col2" class="data row13 col2" >-4</td>
#       <td id="T_5ae9f_row13_col3" class="data row13 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5ae9f_row14_col0" class="data row14 col0" >20170515</td>
#       <td id="T_5ae9f_row14_col1" class="data row14 col1" >1.408451</td>
#       <td id="T_5ae9f_row14_col2" class="data row14 col2" >-3</td>
#       <td id="T_5ae9f_row14_col3" class="data row14 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5ae9f_row15_col0" class="data row15 col0" >20170516</td>
#       <td id="T_5ae9f_row15_col1" class="data row15 col1" >3.611111</td>
#       <td id="T_5ae9f_row15_col2" class="data row15 col2" >-2</td>
#       <td id="T_5ae9f_row15_col3" class="data row15 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5ae9f_row16_col0" class="data row16 col0" >20170517</td>
#       <td id="T_5ae9f_row16_col1" class="data row16 col1" >2.638889</td>
#       <td id="T_5ae9f_row16_col2" class="data row16 col2" >1</td>
#       <td id="T_5ae9f_row16_col3" class="data row16 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5ae9f_row17_col0" class="data row17 col0" >20170518</td>
#       <td id="T_5ae9f_row17_col1" class="data row17 col1" >5.263889</td>
#       <td id="T_5ae9f_row17_col2" class="data row17 col2" >1</td>
#       <td id="T_5ae9f_row17_col3" class="data row17 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5ae9f_row18_col0" class="data row18 col0" >20170519</td>
#       <td id="T_5ae9f_row18_col1" class="data row18 col1" >6.169014</td>
#       <td id="T_5ae9f_row18_col2" class="data row18 col2" >3</td>
#       <td id="T_5ae9f_row18_col3" class="data row18 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5ae9f_row19_col0" class="data row19 col0" >20170520</td>
#       <td id="T_5ae9f_row19_col1" class="data row19 col1" >4.542857</td>
#       <td id="T_5ae9f_row19_col2" class="data row19 col2" >2</td>
#       <td id="T_5ae9f_row19_col3" class="data row19 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5ae9f_level0_ro
# <style type="text/css">
# </style>
# <table id="T_9678d">
#   <caption>Grouped Rovaniemi June Temperature Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9678d_level0_col0" class="col_heading level0 col0" >YR--MODA</th>
#       <th id="T_9678d_level0_col1" class="col_heading level0 col1" >Mean Celsius</th>
#       <th id="T_9678d_level0_col2" class="col_heading level0 col2" >Min Celsius</th>
#       <th id="T_9678d_level0_col3" class="col_heading level0 col3" >Max Celsius</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9678d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9678d_row0_col0" class="data row0 col0" >20170601</td>
#       <td id="T_9678d_row0_col1" class="data row0 col1" >2.152778</td>
#       <td id="T_9678d_row0_col2" class="data row0 col2" >-1</td>
#       <td id="T_9678d_row0_col3" class="data row0 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9678d_row1_col0" class="data row1 col0" >20170602</td>
#       <td id="T_9678d_row1_col1" class="data row1 col1" >2.666667</td>
#       <td id="T_9678d_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_9678d_row1_col3" class="data row1 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9678d_row2_col0" class="data row2 col0" >20170603</td>
#       <td id="T_9678d_row2_col1" class="data row2 col1" >3.472222</td>
#       <td id="T_9678d_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_9678d_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9678d_row3_col0" class="data row3 col0" >20170604</td>
#       <td id="T_9678d_row3_col1" class="data row3 col1" >3.597222</td>
#       <td id="T_9678d_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_9678d_row3_col3" class="data row3 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9678d_row4_col0" class="data row4 col0" >20170605</td>
#       <td id="T_9678d_row4_col1" class="data row4 col1" >7.236111</td>
#       <td id="T_9678d_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_9678d_row4_col3" class="data row4 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9678d_row5_col0" class="data row5 col0" >20170606</td>
#       <td id="T_9678d_row5_col1" class="data row5 col1" >9.513889</td>
#       <td id="T_9678d_row5_col2" class="data row5 col2" >6</td>
#       <td id="T_9678d_row5_col3" class="data row5 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9678d_row6_col0" class="data row6 col0" >20170607</td>
#       <td id="T_9678d_row6_col1" class="data row6 col1" >16.138889</td>
#       <td id="T_9678d_row6_col2" class="data row6 col2" >8</td>
#       <td id="T_9678d_row6_col3" class="data row6 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9678d_row7_col0" class="data row7 col0" >20170608</td>
#       <td id="T_9678d_row7_col1" class="data row7 col1" >18.736111</td>
#       <td id="T_9678d_row7_col2" class="data row7 col2" >12</td>
#       <td id="T_9678d_row7_col3" class="data row7 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9678d_row8_col0" class="data row8 col0" >20170609</td>
#       <td id="T_9678d_row8_col1" class="data row8 col1" >18.569444</td>
#       <td id="T_9678d_row8_col2" class="data row8 col2" >13</td>
#       <td id="T_9678d_row8_col3" class="data row8 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9678d_row9_col0" class="data row9 col0" >20170610</td>
#       <td id="T_9678d_row9_col1" class="data row9 col1" >17.069444</td>
#       <td id="T_9678d_row9_col2" class="data row9 col2" >10</td>
#       <td id="T_9678d_row9_col3" class="data row9 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9678d_row10_col0" class="data row10 col0" >20170611</td>
#       <td id="T_9678d_row10_col1" class="data row10 col1" >11.208333</td>
#       <td id="T_9678d_row10_col2" class="data row10 col2" >7</td>
#       <td id="T_9678d_row10_col3" class="data row10 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9678d_row11_col0" class="data row11 col0" >20170612</td>
#       <td id="T_9678d_row11_col1" class="data row11 col1" >12.236111</td>
#       <td id="T_9678d_row11_col2" class="data row11 col2" >6</td>
#       <td id="T_9678d_row11_col3" class="data row11 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9678d_row12_col0" class="data row12 col0" >20170613</td>
#       <td id="T_9678d_row12_col1" class="data row12 col1" >11.388889</td>
#       <td id="T_9678d_row12_col2" class="data row12 col2" >8</td>
#       <td id="T_9678d_row12_col3" class="data row12 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9678d_row13_col0" class="data row13 col0" >20170614</td>
#       <td id="T_9678d_row13_col1" class="data row13 col1" >13.166667</td>
#       <td id="T_9678d_row13_col2" class="data row13 col2" >7</td>
#       <td id="T_9678d_row13_col3" class="data row13 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9678d_row14_col0" class="data row14 col0" >20170615</td>
#       <td id="T_9678d_row14_col1" class="data row14 col1" >16.142857</td>
#       <td id="T_9678d_row14_col2" class="data row14 col2" >10</td>
#       <td id="T_9678d_row14_col3" class="data row14 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9678d_row15_col0" class="data row15 col0" >20170616</td>
#       <td id="T_9678d_row15_col1" class="data row15 col1" >16.888889</td>
#       <td id="T_9678d_row15_col2" class="data row15 col2" >10</td>
#       <td id="T_9678d_row15_col3" class="data row15 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9678d_row16_col0" class="data row16 col0" >20170617</td>
#       <td id="T_9678d_row16_col1" class="data row16 col1" >15.661972</td>
#       <td id="T_9678d_row16_col2" class="data row16 col2" >12</td>
#       <td id="T_9678d_row16_col3" class="data row16 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9678d_row17_col0" class="data row17 col0" >20170618</td>
#       <td id="T_9678d_row17_col1" class="data row17 col1" >12.472222</td>
#       <td id="T_9678d_row17_col2" class="data row17 col2" >9</td>
#       <td id="T_9678d_row17_col3" class="data row17 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9678d_row18_col0" class="data row18 col0" >20170619</td>
#       <td id="T_9678d_row18_col1" class="data row18 col1" >12.388889</td>
#       <td id="T_9678d_row18_col2" class="data row18 col2" >9</td>
#       <td id="T_9678d_row18_col3" class="data row18 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_9678d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9678d_row19_col0" class="data row19 col0" >20170620</td>
#       <td id="T_9678d_row19_col1" class="data row19 col1" >10.666667</td>
#       <td id="T_9678d_row19_col2" class="data row19 col2" >3</td>
#       <td id="T_9678d_row19_col3" class="data row19 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_9
